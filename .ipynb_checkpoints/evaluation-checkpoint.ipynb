# %%
# %matplotlib notebook
# calling it a second time may prevent some graphics errors
# %matplotlib notebook

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
from tqdm import tqdm

# %%
from model import ResFFN
from data import TwoMoonsDataset
import train
import sklearn.mixture

# %%
torch.manual_seed(1337)
np.random.seed(1337)

# %% [markdown]
# # Train a model
# First we train a FFN with residual connections to ensure smoothness and sensitivity. We use the specifications of [1]: https://arxiv.org/abs/2102.11582

# %%
epochs = 150
batch_size = 128
model = ResFFN(2, 2, 128, 4)
if torch.cuda.is_available(): 
    model = model.cuda()

data_train = TwoMoonsDataset(10000, noise=0.1)
data_val = TwoMoonsDataset(200, noise=0.1)
# data_test = TwoMoonsDataset(200, noise=0.1) Unused

loss_history, accuracy_history = train.train_model(model, data_train, data_val, epochs=epochs, batch_size=batch_size)
# Out:
# ### Epoch 1 / 150
# Validation loss 0.2708; Validation accuracy 0.8850
# ### Epoch 2 / 150
# Validation loss 0.2072; Validation accuracy 0.9100
# ### Epoch 3 / 150
# Validation loss 0.1968; Validation accuracy 0.9300
# ### Epoch 4 / 150
# Validation loss 0.1534; Validation accuracy 0.9450
# ### Epoch 5 / 150
# Validation loss 0.1255; Validation accuracy 0.9450
# ### Epoch 6 / 150
# Validation loss 0.1201; Validation accuracy 0.9500
# ### Epoch 7 / 150
# Validation loss 0.1341; Validation accuracy 0.9500
# ### Epoch 8 / 150
# Validation loss 0.1088; Validation accuracy 0.9600
# ### Epoch 9 / 150
# Validation loss 0.1037; Validation accuracy 0.9550
# ### Epoch 10 / 150
# Validation loss 0.0964; Validation accuracy 0.9650
# ### Epoch 11 / 150
# Validation loss 0.1002; Validation accuracy 0.9650
# ### Epoch 12 / 150
# Validation loss 0.0798; Validation accuracy 0.9750
# ### Epoch 13 / 150
# Validation loss 0.0863; Validation accuracy 0.9800
# ### Epoch 14 / 150
# Validation loss 0.0917; Validation accuracy 0.9750
# ### Epoch 15 / 150
# Validation loss 0.0898; Validation accuracy 0.9650
# ### Epoch 16 / 150
# Validation loss 0.0862; Validation accuracy 0.9800
# ### Epoch 17 / 150
# Validation loss 0.0849; Validation accuracy 0.9800
# ### Epoch 18 / 150
# Validation loss 0.0729; Validation accuracy 0.9700
# ### Epoch 19 / 150
# Validation loss 0.0741; Validation accuracy 0.9800
# ### Epoch 20 / 150
# Validation loss 0.0692; Validation accuracy 0.9700
# ### Epoch 21 / 150
# Validation loss 0.0766; Validation accuracy 0.9850
# ### Epoch 22 / 150
# Validation loss 0.0651; Validation accuracy 0.9800
# ### Epoch 23 / 150
# Validation loss 0.0837; Validation accuracy 0.9750
# ### Epoch 24 / 150
# Validation loss 0.0719; Validation accuracy 0.9750
# ### Epoch 25 / 150
# Validation loss 0.0793; Validation accuracy 0.9750
# ### Epoch 26 / 150
# Validation loss 0.0948; Validation accuracy 0.9700
# ### Epoch 27 / 150
# Validation loss 0.0768; Validation accuracy 0.9850
# ### Epoch 28 / 150
# Validation loss 0.0677; Validation accuracy 0.9800
# ### Epoch 29 / 150
# Validation loss 0.0705; Validation accuracy 0.9850
# ### Epoch 30 / 150
# Validation loss 0.0647; Validation accuracy 0.9800
# ### Epoch 31 / 150
# Validation loss 0.0735; Validation accuracy 0.9800
# ### Epoch 32 / 150
# Validation loss 0.0684; Validation accuracy 0.9800
# ### Epoch 33 / 150
# Validation loss 0.0859; Validation accuracy 0.9750
# ### Epoch 34 / 150
# Validation loss 0.0692; Validation accuracy 0.9800
# ### Epoch 35 / 150
# Validation loss 0.0615; Validation accuracy 0.9850
# ### Epoch 36 / 150
# Validation loss 0.0697; Validation accuracy 0.9750
# ### Epoch 37 / 150
# Validation loss 0.0634; Validation accuracy 0.9850
# ### Epoch 38 / 150
# Validation loss 0.0656; Validation accuracy 0.9850
# ### Epoch 39 / 150
# Validation loss 0.0696; Validation accuracy 0.9850
# ### Epoch 40 / 150
# Validation loss 0.0570; Validation accuracy 0.9850
# ### Epoch 41 / 150
# Validation loss 0.0652; Validation accuracy 0.9800
# ### Epoch 42 / 150
# Validation loss 0.0685; Validation accuracy 0.9800
# ### Epoch 43 / 150
# Validation loss 0.0769; Validation accuracy 0.9800
# ### Epoch 44 / 150
# Validation loss 0.0630; Validation accuracy 0.9850
# ### Epoch 45 / 150
# Validation loss 0.0628; Validation accuracy 0.9850
# ### Epoch 46 / 150
# Validation loss 0.0663; Validation accuracy 0.9850
# ### Epoch 47 / 150
# Validation loss 0.0757; Validation accuracy 0.9750
# ### Epoch 48 / 150
# Validation loss 0.0627; Validation accuracy 0.9850
# ### Epoch 49 / 150
# Validation loss 0.0652; Validation accuracy 0.9850
# ### Epoch 50 / 150
# Validation loss 0.0770; Validation accuracy 0.9750
# ### Epoch 51 / 150
# Validation loss 0.0950; Validation accuracy 0.9750
# ### Epoch 52 / 150
# Validation loss 0.0650; Validation accuracy 0.9900
# ### Epoch 53 / 150
# Validation loss 0.0777; Validation accuracy 0.9750
# ### Epoch 54 / 150
# Validation loss 0.0640; Validation accuracy 0.9900
# ### Epoch 55 / 150
# Validation loss 0.0786; Validation accuracy 0.9750
# ### Epoch 56 / 150
# Validation loss 0.0749; Validation accuracy 0.9850
# ### Epoch 57 / 150
# Validation loss 0.0591; Validation accuracy 0.9900
# ### Epoch 58 / 150
# Validation loss 0.0666; Validation accuracy 0.9800
# ### Epoch 59 / 150
# Validation loss 0.0558; Validation accuracy 0.9900
# ### Epoch 60 / 150
# Validation loss 0.0640; Validation accuracy 0.9850
# ### Epoch 61 / 150
# Validation loss 0.0654; Validation accuracy 0.9850
# ### Epoch 62 / 150
# Validation loss 0.0650; Validation accuracy 0.9850
# ### Epoch 63 / 150
# Validation loss 0.0575; Validation accuracy 0.9850
# ### Epoch 64 / 150
# Validation loss 0.0640; Validation accuracy 0.9850
# ### Epoch 65 / 150
# Validation loss 0.0643; Validation accuracy 0.9750
# ### Epoch 66 / 150
# Validation loss 0.0625; Validation accuracy 0.9850
# ### Epoch 67 / 150
# Validation loss 0.0551; Validation accuracy 0.9900
# ### Epoch 68 / 150
# Validation loss 0.0560; Validation accuracy 0.9800
# ### Epoch 69 / 150
# Validation loss 0.0632; Validation accuracy 0.9900
# ### Epoch 70 / 150
# Validation loss 0.0637; Validation accuracy 0.9900
# ### Epoch 71 / 150
# Validation loss 0.0612; Validation accuracy 0.9900
# ### Epoch 72 / 150
# Validation loss 0.0544; Validation accuracy 0.9850
# ### Epoch 73 / 150
# Validation loss 0.0788; Validation accuracy 0.9800
# ### Epoch 74 / 150
# Validation loss 0.0537; Validation accuracy 0.9900
# ### Epoch 75 / 150
# Validation loss 0.0629; Validation accuracy 0.9850
# ### Epoch 76 / 150
# Validation loss 0.0538; Validation accuracy 0.9800
# ### Epoch 77 / 150
# Validation loss 0.0860; Validation accuracy 0.9750
# ### Epoch 78 / 150
# Validation loss 0.0532; Validation accuracy 0.9900
# ### Epoch 79 / 150
# Validation loss 0.0555; Validation accuracy 0.9800
# ### Epoch 80 / 150
# Validation loss 0.0600; Validation accuracy 0.9900
# ### Epoch 81 / 150
# Validation loss 0.0638; Validation accuracy 0.9850
# ### Epoch 82 / 150
# Validation loss 0.0574; Validation accuracy 0.9900
# ### Epoch 83 / 150
# Validation loss 0.0631; Validation accuracy 0.9850
# ### Epoch 84 / 150
# Validation loss 0.0587; Validation accuracy 0.9850
# ### Epoch 85 / 150
# Validation loss 0.0545; Validation accuracy 0.9850
# ### Epoch 86 / 150
# Validation loss 0.0512; Validation accuracy 0.9850
# ### Epoch 87 / 150
# Validation loss 0.0521; Validation accuracy 0.9900
# ### Epoch 88 / 150
# Validation loss 0.0502; Validation accuracy 0.9850
# ### Epoch 89 / 150
# Validation loss 0.0577; Validation accuracy 0.9850
# ### Epoch 90 / 150
# Validation loss 0.0568; Validation accuracy 0.9850
# ### Epoch 91 / 150
# Validation loss 0.0512; Validation accuracy 0.9900
# ### Epoch 92 / 150
# Validation loss 0.0507; Validation accuracy 0.9900
# ### Epoch 93 / 150
# Validation loss 0.0547; Validation accuracy 0.9850
# ### Epoch 94 / 150
# Validation loss 0.0568; Validation accuracy 0.9850
# ### Epoch 95 / 150
# Validation loss 0.0509; Validation accuracy 0.9850
# ### Epoch 96 / 150
# Validation loss 0.0512; Validation accuracy 0.9900
# ### Epoch 97 / 150
# Validation loss 0.0565; Validation accuracy 0.9850
# ### Epoch 98 / 150
# Validation loss 0.0447; Validation accuracy 0.9900
# ### Epoch 99 / 150
# Validation loss 0.0534; Validation accuracy 0.9900
# ### Epoch 100 / 150
# Validation loss 0.0610; Validation accuracy 0.9800
# ### Epoch 101 / 150
# Validation loss 0.0559; Validation accuracy 0.9900
# ### Epoch 102 / 150
# Validation loss 0.0563; Validation accuracy 0.9850
# ### Epoch 103 / 150
# Validation loss 0.0546; Validation accuracy 0.9900
# ### Epoch 104 / 150
# Validation loss 0.0519; Validation accuracy 0.9900
# ### Epoch 105 / 150
# Validation loss 0.0604; Validation accuracy 0.9850
# ### Epoch 106 / 150
# Validation loss 0.0546; Validation accuracy 0.9900
# ### Epoch 107 / 150
# Validation loss 0.0551; Validation accuracy 0.9850
# ### Epoch 108 / 150
# Validation loss 0.0595; Validation accuracy 0.9900
# ### Epoch 109 / 150
# Validation loss 0.0539; Validation accuracy 0.9900
# ### Epoch 110 / 150
# Validation loss 0.0572; Validation accuracy 0.9850
# ### Epoch 111 / 150
# Validation loss 0.0601; Validation accuracy 0.9900
# ### Epoch 112 / 150
# Validation loss 0.0533; Validation accuracy 0.9850
# ### Epoch 113 / 150
# Validation loss 0.0591; Validation accuracy 0.9900
# ### Epoch 114 / 150
# Validation loss 0.0592; Validation accuracy 0.9850
# ### Epoch 115 / 150
# Validation loss 0.0487; Validation accuracy 0.9900
# ### Epoch 116 / 150
# Validation loss 0.0504; Validation accuracy 0.9900
# ### Epoch 117 / 150
# Validation loss 0.0520; Validation accuracy 0.9900
# ### Epoch 118 / 150
# Validation loss 0.0570; Validation accuracy 0.9850
# ### Epoch 119 / 150
# Validation loss 0.0615; Validation accuracy 0.9900
# ### Epoch 120 / 150
# Validation loss 0.0543; Validation accuracy 0.9850
# ### Epoch 121 / 150
# Validation loss 0.0523; Validation accuracy 0.9850
# ### Epoch 122 / 150
# Validation loss 0.0545; Validation accuracy 0.9900
# ### Epoch 123 / 150
# Validation loss 0.0533; Validation accuracy 0.9900
# ### Epoch 124 / 150
# Validation loss 0.0598; Validation accuracy 0.9900
# ### Epoch 125 / 150
# Validation loss 0.0455; Validation accuracy 0.9900
# ### Epoch 126 / 150
# Validation loss 0.0520; Validation accuracy 0.9850
# ### Epoch 127 / 150
# Validation loss 0.0492; Validation accuracy 0.9900
# ### Epoch 128 / 150
# Validation loss 0.0687; Validation accuracy 0.9900
# ### Epoch 129 / 150
# Validation loss 0.0519; Validation accuracy 0.9900
# ### Epoch 130 / 150
# Validation loss 0.0528; Validation accuracy 0.9850
# ### Epoch 131 / 150
# Validation loss 0.0526; Validation accuracy 0.9900
# ### Epoch 132 / 150
# Validation loss 0.0484; Validation accuracy 0.9850
# ### Epoch 133 / 150
# Validation loss 0.0527; Validation accuracy 0.9900
# ### Epoch 134 / 150
# Validation loss 0.0514; Validation accuracy 0.9850
# ### Epoch 135 / 150
# Validation loss 0.0493; Validation accuracy 0.9900
# ### Epoch 136 / 150
# Validation loss 0.0493; Validation accuracy 0.9900
# ### Epoch 137 / 150
# Validation loss 0.0548; Validation accuracy 0.9900
# ### Epoch 138 / 150
# Validation loss 0.0546; Validation accuracy 0.9900
# ### Epoch 139 / 150
# Validation loss 0.0529; Validation accuracy 0.9900
# ### Epoch 140 / 150
# Validation loss 0.0516; Validation accuracy 0.9900
# ### Epoch 141 / 150
# Validation loss 0.0616; Validation accuracy 0.9900
# ### Epoch 142 / 150
# Validation loss 0.0475; Validation accuracy 0.9900
# ### Epoch 143 / 150
# Validation loss 0.0500; Validation accuracy 0.9900
# ### Epoch 144 / 150
# Validation loss 0.0551; Validation accuracy 0.9900
# ### Epoch 145 / 150
# Validation loss 0.0560; Validation accuracy 0.9900
# ### Epoch 146 / 150
# Validation loss 0.0530; Validation accuracy 0.9850
# ### Epoch 147 / 150
# Validation loss 0.0467; Validation accuracy 0.9900
# ### Epoch 148 / 150
# Validation loss 0.0487; Validation accuracy 0.9900
# ### Epoch 149 / 150
# Validation loss 0.0482; Validation accuracy 0.9850
# ### Epoch 150 / 150
# Validation loss 0.0471; Validation accuracy 0.9900

# %% [markdown]
# # Fit Gaussian Mixture Model
# I found that estimating the covariance matrix per class from the feature representations directly leads to singular matrices. Investigating this issue I tried several things to circumcome this issue:
# - Use a Leaky ReLU to prevent fixed "0"s in feature represenations, leading to zero variance components in the feature space which causes singularity
# - Don't apply any non-linearity when extracting features to induce more variance
#
# Finally, instead of estimating the mean and covariance directly from feature represenations per class I instead fitted a 1-component GMM to estimate a Gaussian distribution per class in the feature space.

# %%
zs, ys = [], []
model.eval()
data_loader_train = torch.utils.data.DataLoader(data_train, batch_size=128, drop_last=False)
with torch.no_grad():
    for (x, y) in tqdm(data_loader_train):
        x = x.float()
        if torch.cuda.is_available():
            x = x.cuda()
        zs.append(model(x, return_features=True))
        ys.append(y)
z = torch.cat(zs).detach().cpu().numpy()
y = torch.cat(ys).detach().cpu().numpy()
# Out:
# 100%|██████████| 79/79 [00:00<00:00, 341.27it/s]

# %%
components, mixture_coefs = {}, {}
for label in np.unique(y):
    components[label] = sklearn.mixture.GaussianMixture(n_components=1, covariance_type='full')
    components[label].fit(z[y == label])
    mixture_coefs[label] = (y == label).sum() / y.shape[0]

# %%
# Create a mesh and get feature representations of all points within the mesh
X, Y = np.meshgrid(np.linspace(-3., 3., 100), np.linspace(-3., 3., 100))
XX = np.array([X.ravel(), Y.ravel()]).T
data_mesh = torch.utils.data.TensorDataset(torch.Tensor(XX))
data_loader_mesh = torch.utils.data.DataLoader(data_mesh, batch_size=128, drop_last=False)

# %%
zs_mesh = []
with torch.no_grad():
    for (x,) in tqdm(data_loader_mesh):
        x = x.float()
        if torch.cuda.is_available():
            x = x.cuda()
        zs_mesh.append(model(x, return_features=True))
z_mesh = torch.cat(zs_mesh).detach().cpu().numpy()
# Out:
# 100%|██████████| 79/79 [00:00<00:00, 253.32it/s]

# %%
scores = np.zeros(z_mesh.shape[0])
for label in components:
    scores += mixture_coefs[label] * components[label].score_samples(z_mesh)
scores = scores.reshape(X.shape)

# %%
plt.pcolormesh(X, Y, np.exp(5e-3 * scores))
# Out:
# <img src="data:image/png;base64,..." width="640">
# /home/dominik/.local/lib/python3.6/site-packages/ipykernel_launcher.py:1: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   """Entry point for launching an IPython kernel.
